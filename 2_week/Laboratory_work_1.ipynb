# %% [markdown]
# <a href="https://colab.research.google.com/github/RodjonSobiani/ml_learning/blob/main/Laboratory_work_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/CSV/Non-residential outliers.csv').drop(columns=['Series_title_3', 'Series_title_4', 'Series_title_5']).set_index(['Period'])
data.head()
# Out:
#         Series_reference  Data_value Suppressed Status  Units  Magnitude  \
# Period
# 1990.01        BLDM.SLE2           0          n      F  value          0
# 1990.02        BLDM.SLE2           0          n      F  value          0
# 1990.03        BLDM.SLE2           0          n      F  value          0
# 1990.04        BLDM.SLE2           0          n      F  value          0
# 1990.05        BLDM.SLE2    45000000          n      F  value          0
#
#                          Subject  \
# Period
# 1990.01  Building Consents - BLD
# 1990.02  Building Consents - BLD
# 1990.03  Building Consents - BLD
# 1990.04  Building Consents - BLD
# 1990.05  Building Consents - BLD
#
#                                                      Group  \
# Period
# 1990.01  Non-residential buildings $25m and over (Disc ...
# 1990.02  Non-residential buildings $25m and over (Disc ...
# 1990.03  Non-residential buildings $25m and over (Disc ...
# ...

# %%
data.head(10)
# Out:
#         Series_reference  Data_value Suppressed Status  Units  Magnitude  \
# Period
# 1990.01        BLDM.SLE2           0          n      F  value          0
# 1990.02        BLDM.SLE2           0          n      F  value          0
# 1990.03        BLDM.SLE2           0          n      F  value          0
# 1990.04        BLDM.SLE2           0          n      F  value          0
# 1990.05        BLDM.SLE2    45000000          n      F  value          0
# 1990.06        BLDM.SLE2           0          n      F  value          0
# 1990.07        BLDM.SLE2           0          n      F  value          0
# 1990.08        BLDM.SLE2           0          n      F  value          0
# 1990.09        BLDM.SLE2           0          n      F  value          0
# 1990.10        BLDM.SLE2    25734285          n      F  value          0
#
#                          Subject  \
# Period
# 1990.01  Building Consents - BLD
# 1990.02  Building Consents - BLD
# 1990.03  Building Consents - BLD
# ...

# %%
data.tail()
# Out:
#         Series_reference  Data_value Suppressed Status    Units  Magnitude  \
# Period
# 2021.12         BLDM.SXC           0          n      F  Dollars          0
# 2022.01         BLDM.SXC           0          n      F  Dollars          0
# 2022.02         BLDM.SXC           0          n      F  Dollars          0
# 2022.03         BLDM.SXC           0          n      F  Dollars          0
# 2022.04         BLDM.SXC           0          n      F  Dollars          0
#
#                          Subject                              Group  \
# Period
# 2021.12  Building Consents - BLD  Non-residential building outliers
# 2022.01  Building Consents - BLD  Non-residential building outliers
# 2022.02  Building Consents - BLD  Non-residential building outliers
# 2022.03  Building Consents - BLD  Non-residential building outliers
# 2022.04  Building Consents - BLD  Non-residential building outliers
#
#                  Series_title_1 Series_title_2
# Period
# ...

# %%
data.describe()
# Out:
#          Data_value  Magnitude
# count  8.600000e+02      860.0
# mean   1.477151e+07        0.0
# std    3.778688e+07        0.0
# min    0.000000e+00        0.0
# 25%    0.000000e+00        0.0
# 50%    0.000000e+00        0.0
# 75%    0.000000e+00        0.0
# max    3.400237e+08        0.0

# %%
data.dtypes
# Out:
# Series_reference    object
# Data_value           int64
# Suppressed          object
# Status              object
# Units               object
# Magnitude            int64
# Subject             object
# Group               object
# Series_title_1      object
# Series_title_2      object
# dtype: object

# %%
data.shape
# Out:
# (860, 10)

# %%
data.size
# Out:
# 8600

# %%
data.groupby('Period').aggregate({'Data_value':'mean'}).head(10)
# Out:
#          Data_value
# Period
# 1990.01         0.0
# 1990.02         0.0
# 1990.03         0.0
# 1990.04         0.0
# 1990.05  22500000.0
# 1990.06         0.0
# 1990.07         0.0
# 1990.08         0.0
# 1990.09         0.0
# 1990.10  12867142.5

# %%
data.iloc[0:7,0:3]
# Out:
#         Series_reference  Data_value Suppressed
# Period
# 1990.01        BLDM.SLE2           0          n
# 1990.02        BLDM.SLE2           0          n
# 1990.03        BLDM.SLE2           0          n
# 1990.04        BLDM.SLE2           0          n
# 1990.05        BLDM.SLE2    45000000          n
# 1990.06        BLDM.SLE2           0          n
# 1990.07        BLDM.SLE2           0          n

# %%
data.iloc[[0, 3, 5], [0, 3, -1]]
# Out:
#         Series_reference Status Series_title_2
# Period
# 1990.01        BLDM.SLE2      F          Value
# 1990.04        BLDM.SLE2      F          Value
# 1990.06        BLDM.SLE2      F          Value

# %%
data.iloc[:,-3:-1].head()
# Out:
#                                                      Group  \
# Period
# 1990.01  Non-residential buildings $25m and over (Disc ...
# 1990.02  Non-residential buildings $25m and over (Disc ...
# 1990.03  Non-residential buildings $25m and over (Disc ...
# 1990.04  Non-residential buildings $25m and over (Disc ...
# 1990.05  Non-residential buildings $25m and over (Disc ...
#
#                 Series_title_1
# Period
# 1990.01  Large non-residential
# 1990.02  Large non-residential
# 1990.03  Large non-residential
# 1990.04  Large non-residential
# 1990.05  Large non-residential

# %%
type(data.iloc[:,-3:-1])
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[:,1].head()
# Out:
# Period
# 1990.01           0
# 1990.02           0
# 1990.03           0
# 1990.04           0
# 1990.05    45000000
# Name: Data_value, dtype: int64

# %%
type(data.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
my_series_1 = pd.Series([1, 2, 3], index=['Tom', 'Tim', 'Sam'])
my_series_1
# Out:
# Tom    1
# Tim    2
# Sam    3
# dtype: int64

# %%
my_series_2 = pd.Series([4, 5, 6], index=['Tom', 'Tim', 'Sam'])
my_series_2
# Out:
# Tom    4
# Tim    5
# Sam    6
# dtype: int64

# %%
pd.DataFrame({'col_1':my_series_1, 'col_2':my_series_2})
# Out:
#      col_1  col_2
# Tom      1      4
# Tim      2      5
# Sam      3      6

# %%
type(data['Units'])
# Out:
# pandas.core.series.Series

# %%
type(data[['Units']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Convert float64index to Integer
data.index = data.index.astype(int)
data.index = pd.to_datetime(data.index, yearfirst=True)
data.index = data.index.year

# data.index = data.index.map(lambda x : int(x))

# %%
data.head(10)
# Out:
#        Series_reference  Data_value Suppressed Status  Units  Magnitude  \
# Period
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2    45000000          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2           0          n      F  value          0
# 1970          BLDM.SLE2    25734285          n      F  value          0
#
#                         Subject  \
# Period
# 1970    Building Consents - BLD
# 1970    Building Consents - BLD
# 1970    Building Consents - BLD
# ...
